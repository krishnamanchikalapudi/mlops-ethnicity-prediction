# %%
dataset_path = "./dataset"
dataset_original = "{}/{}".format(dataset_path, 'ethnicity.csv')
dataset_original
# Out:
# './dataset/ethnicity.csv'

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(dataset_original)
df
# Out:
#        age  ethnicity  gender                        img_name  \
# 0        1          2       0  20161219203650636.jpg.chip.jpg
# 1        1          2       0  20161219222752047.jpg.chip.jpg
# 2        1          2       0  20161219222832191.jpg.chip.jpg
# 3        1          2       0  20161220144911423.jpg.chip.jpg
# 4        1          2       0  20161220144914327.jpg.chip.jpg
# ...    ...        ...     ...                             ...
# 23700   99          0       1  20170120221920654.jpg.chip.jpg
# 23701   99          1       1  20170120134639935.jpg.chip.jpg
# 23702   99          2       1  20170110182418864.jpg.chip.jpg
# 23703   99          2       1  20170117195405372.jpg.chip.jpg
# 23704   99          0       1  20170110182052119.jpg.chip.jpg
#
#                                                   pixels
# 0      129 128 128 126 127 130 133 135 139 142 145 14...
# 1      164 74 111 168 169 171 175 182 184 188 193 199...
# ...

# %%
names_ethnicity = ['White', 'Black', 'Asian', 'Indian', 'Other']
ethnicity_unique = df['ethnicity'].unique()
ethnicity_unique = np.sort(ethnicity_unique)
ethnicity_unique
# Out:
# array([0, 1, 2, 3, 4])

# %%
for x in ethnicity_unique:
  print(f'id: {x} value: {names_ethnicity[x]}')
# Out:
# id: 0 value: White
# id: 1 value: Black
# id: 2 value: Asian
# id: 3 value: Indian
# id: 4 value: Other

# %%
def ethnicity_remove(num, filename):
    df_no_ethnicity = df[df.ethnicity !=  num]
    df_no_ethnicity.to_csv(filename)
    print (f"file saved at {filename} ")

# %%
def ethnicity_unique(df):
    ethnicity_unique = df['ethnicity'].unique()
    ethnicity_unique = np.sort(ethnicity_unique)
    for x in ethnicity_unique:
        print(f'id: {x} value: {names_ethnicity[x]}')

# %% [markdown]
# ## Remove 'white', ethnicity=0

# %%
csv_no_white = "{}/{}".format(dataset_path, 'ethnicity_no_white.csv')
ethnicity_remove(0, csv_no_white)

# Load file
no_white_df = pd.read_csv(csv_no_white)
ethnicity_unique(no_white_df)
no_white_df
# Out:
# file saved at ./dataset/ethnicity_no_white.csv
# id: 1 value: Black
# id: 2 value: Asian
# id: 3 value: Indian
# id: 4 value: Other
#        Unnamed: 0  age  ethnicity  gender                        img_name  \
# 0               0    1          2       0  20161219203650636.jpg.chip.jpg
# 1               1    1          2       0  20161219222752047.jpg.chip.jpg
# 2               2    1          2       0  20161219222832191.jpg.chip.jpg
# 3               3    1          2       0  20161220144911423.jpg.chip.jpg
# 4               4    1          2       0  20161220144914327.jpg.chip.jpg
# ...           ...  ...        ...     ...                             ...
# 13622       23686   96          2       1  20170110182504813.jpg.chip.jpg
# 13623       23688   96          1       1  20170110183853718.jpg.chip.jpg
# 13624       23701   99          1       1  20170120134639935.jpg.chip.jpg
# 13625       23702   99          2       1  20170110182418864.jpg.chip.jpg
# ...

# %% [markdown]
# ## Remove 'black', ethnicity=1

# %%
csv_no_black = "{}/{}".format(dataset_path, 'ethnicity_no_black.csv')
ethnicity_remove(1, csv_no_black)

# load file
no_black_df = pd.read_csv(csv_no_black)
ethnicity_unique(no_black_df)
no_black_df
# Out:
# file saved at ./dataset/ethnicity_no_black.csv
# id: 0 value: White
# id: 2 value: Asian
# id: 3 value: Indian
# id: 4 value: Other
#        Unnamed: 0  age  ethnicity  gender                        img_name  \
# 0               0    1          2       0  20161219203650636.jpg.chip.jpg
# 1               1    1          2       0  20161219222752047.jpg.chip.jpg
# 2               2    1          2       0  20161219222832191.jpg.chip.jpg
# 3               3    1          2       0  20161220144911423.jpg.chip.jpg
# 4               4    1          2       0  20161220144914327.jpg.chip.jpg
# ...           ...  ...        ...     ...                             ...
# 19174       23699   99          0       1  20170120134718759.jpg.chip.jpg
# 19175       23700   99          0       1  20170120221920654.jpg.chip.jpg
# 19176       23702   99          2       1  20170110182418864.jpg.chip.jpg
# 19177       23703   99          2       1  20170117195405372.jpg.chip.jpg
# ...

# %% [markdown]
# ## Remove 'Asian', ethnicity=2

# %%
csv_no_asian = "{}/{}".format(dataset_path, 'ethnicity_no_asian.csv')
ethnicity_remove(2, csv_no_asian)

# load file
no_asian_df = pd.read_csv(csv_no_asian)
ethnicity_unique(no_asian_df)
no_asian_df
# Out:
# file saved at ./dataset/ethnicity_no_asian.csv
# id: 0 value: White
# id: 1 value: Black
# id: 3 value: Indian
# id: 4 value: Other
#        Unnamed: 0  age  ethnicity  gender                        img_name  \
# 0              40    1          3       0  20161219224423280.jpg.chip.jpg
# 1              41    1          3       0  20161219225121728.jpg.chip.jpg
# 2              42    1          3       0  20161219225149888.jpg.chip.jpg
# 3              43    1          3       0  20161219225241152.jpg.chip.jpg
# 4              44    1          3       0  20161219225242908.jpg.chip.jpg
# ...           ...  ...        ...     ...                             ...
# 20266       23698   99          0       1  20170120133837030.jpg.chip.jpg
# 20267       23699   99          0       1  20170120134718759.jpg.chip.jpg
# 20268       23700   99          0       1  20170120221920654.jpg.chip.jpg
# 20269       23701   99          1       1  20170120134639935.jpg.chip.jpg
# ...

# %% [markdown]
# ## Remove 'Indian', ethnicity=3

# %%
csv_no_indian = "{}/{}".format(dataset_path, 'ethnicity_no_indian.csv')
ethnicity_remove(3, csv_no_indian)

# load file
no_indian_df = pd.read_csv(csv_no_indian)
ethnicity_unique(no_indian_df)
no_indian_df
# Out:
# file saved at ./dataset/ethnicity_no_indian.csv
# id: 0 value: White
# id: 1 value: Black
# id: 2 value: Asian
# id: 4 value: Other
#        Unnamed: 0  age  ethnicity  gender                        img_name  \
# 0               0    1          2       0  20161219203650636.jpg.chip.jpg
# 1               1    1          2       0  20161219222752047.jpg.chip.jpg
# 2               2    1          2       0  20161219222832191.jpg.chip.jpg
# 3               3    1          2       0  20161220144911423.jpg.chip.jpg
# 4               4    1          2       0  20161220144914327.jpg.chip.jpg
# ...           ...  ...        ...     ...                             ...
# 19725       23700   99          0       1  20170120221920654.jpg.chip.jpg
# 19726       23701   99          1       1  20170120134639935.jpg.chip.jpg
# 19727       23702   99          2       1  20170110182418864.jpg.chip.jpg
# 19728       23703   99          2       1  20170117195405372.jpg.chip.jpg
# ...

# %% [markdown]
# ## Remove 'Other', ethnicity=4

# %%
csv_no_other = "{}/{}".format(dataset_path, 'ethnicity_no_other.csv')
ethnicity_remove(4, csv_no_other)

# load file
no_other_df = pd.read_csv(csv_no_other)
ethnicity_unique(no_other_df)
no_other_df
# Out:
# file saved at ./dataset/ethnicity_no_other.csv
# id: 0 value: White
# id: 1 value: Black
# id: 2 value: Asian
# id: 3 value: Indian
#        Unnamed: 0  age  ethnicity  gender                        img_name  \
# 0               0    1          2       0  20161219203650636.jpg.chip.jpg
# 1               1    1          2       0  20161219222752047.jpg.chip.jpg
# 2               2    1          2       0  20161219222832191.jpg.chip.jpg
# 3               3    1          2       0  20161220144911423.jpg.chip.jpg
# 4               4    1          2       0  20161220144914327.jpg.chip.jpg
# ...           ...  ...        ...     ...                             ...
# 22008       23700   99          0       1  20170120221920654.jpg.chip.jpg
# 22009       23701   99          1       1  20170120134639935.jpg.chip.jpg
# 22010       23702   99          2       1  20170110182418864.jpg.chip.jpg
# 22011       23703   99          2       1  20170117195405372.jpg.chip.jpg
# ...
